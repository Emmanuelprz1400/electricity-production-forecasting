# %% [markdown]
# <a href="https://colab.research.google.com/github/Emmanuelprz1400/electricity-production-forecasting/blob/main/electricity_forecasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bibliotecas y funciones

# %%
import numpy as np
import pandas as pd

import itertools

from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX

from sklearn.metrics import mean_squared_error

import matplotlib.pyplot as plt

# %%
def p_value_adfuller(data):
        fuller_test = adfuller(data)
        print('P-value: ',fuller_test[1])
        if fuller_test[1] <= 0.05:
            print('Se rechaza la hipótesis nula, los datos son estacionarios')
        else:
            print('No se rechaza la hipóteis nula, los datos no son estacionarios')

# %% [markdown]
# # Lectura y exploración de la Serie de Tiempo

# %%
file = 'https://raw.githubusercontent.com/Emmanuelprz1400/electricity-production-forecasting/main/Datos/IPG2211A2N%20_2023_01.csv'

datos = pd.read_csv(file,
                    index_col = [0],
                    parse_dates=['DATE']
                    )
datos = datos.loc['2000-01-01':]
datos.columns = ['Producción']  # NAICS 2211

datos
# Out:
#             Producción
# DATE
# 2000-01-01    100.9623
# 2000-02-01     93.1065
# 2000-03-01     87.0234
# 2000-04-01     80.4433
# 2000-05-01     83.4549
# ...                ...
# 2022-09-01    100.4154
# 2022-10-01     91.0391
# 2022-11-01    100.8168
# 2022-12-01    120.8932
# 2023-01-01    115.5170
#
# [277 rows x 1 columns]

# %% [markdown]
# ## Asegurar el orden y la continuidad de la serie de tiempo

# %%
# La monotonicidad es una propiedad matemática que indica que una función
# determinada mantiene un orden no creciente o decreciente en todo su dominio

datos.index.is_monotonic_increasing
# Out:
# True

# %%
datos.index
# Out:
# DatetimeIndex(['2000-01-01', '2000-02-01', '2000-03-01', '2000-04-01',
#                '2000-05-01', '2000-06-01', '2000-07-01', '2000-08-01',
#                '2000-09-01', '2000-10-01',
#                ...
#                '2022-04-01', '2022-05-01', '2022-06-01', '2022-07-01',
#                '2022-08-01', '2022-09-01', '2022-10-01', '2022-11-01',
#                '2022-12-01', '2023-01-01'],
#               dtype='datetime64[ns]', name='DATE', length=277, freq=None)

# %%
# para algunas funciones de ST es importante indicar la frecuencia de nuestros datos
datos.index.freq = datos.index.inferred_freq
datos.index
# Out:
# DatetimeIndex(['2000-01-01', '2000-02-01', '2000-03-01', '2000-04-01',
#                '2000-05-01', '2000-06-01', '2000-07-01', '2000-08-01',
#                '2000-09-01', '2000-10-01',
#                ...
#                '2022-04-01', '2022-05-01', '2022-06-01', '2022-07-01',
#                '2022-08-01', '2022-09-01', '2022-10-01', '2022-11-01',
#                '2022-12-01', '2023-01-01'],
#               dtype='datetime64[ns]', name='DATE', length=277, freq='MS')

# %% [markdown]
# Para más información de las frecuencias en pandas consultar el apartado DateOffset objects en [este enlace](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html)

# %% [markdown]
# ### Ejemplo de Serie discontinua

# %%
df  = datos.drop( ['2000-03-01', '2015-09-01', '2019-07-01'])
df
# Out:
#             Producción
# DATE
# 2000-01-01    100.9623
# 2000-02-01     93.1065
# 2000-04-01     80.4433
# 2000-05-01     83.4549
# 2000-06-01     89.9617
# ...                ...
# 2022-09-01    100.4154
# 2022-10-01     91.0391
# 2022-11-01    100.8168
# 2022-12-01    120.8932
# 2023-01-01    115.5170
#
# [274 rows x 1 columns]

# %%
df.index.is_monotonic_increasing
# Out:
# True

# %%
# para algunas funciones de ST es importante indicar la frecuencia de nuestros datos
df.index.freq = df.index.inferred_freq
df.index
# Out:
# DatetimeIndex(['2000-01-01', '2000-02-01', '2000-04-01', '2000-05-01',
#                '2000-06-01', '2000-07-01', '2000-08-01', '2000-09-01',
#                '2000-10-01', '2000-11-01',
#                ...
#                '2022-04-01', '2022-05-01', '2022-06-01', '2022-07-01',
#                '2022-08-01', '2022-09-01', '2022-10-01', '2022-11-01',
#                '2022-12-01', '2023-01-01'],
#               dtype='datetime64[ns]', name='DATE', length=274, freq=None)

# %%
df.index.min(), df.index.max()
# Out:
# (Timestamp('2000-01-01 00:00:00'), Timestamp('2023-01-01 00:00:00'))

# %%
# Creamos una Series de pandas con las fechas esperadas para compararlo con las
# fechas en nuestra serie de tiempo.

obsEsperadas = pd.Series(data=pd.date_range(start=df.index.min(), end=df.index.max(), freq='MS'))

# Filtramos las fechas, en las obserbvaciones Esperadas que no aparecen en
# nuestra serie de tiempo

faltantes = obsEsperadas[~ obsEsperadas.isin(df.index)]

for i in faltantes.dt.strftime('%Y/%m/%d'):
    print(i)
# Out:
# 2000/03/01
# 2015/09/01
# 2019/07/01

# %% [markdown]
# ## Exploración y Visualización de la Serie Temporal

# %%
datos['Producción'].plot(figsize=(10,4), title='Producción de Electricidad y Gas')
plt.show()

# %%
datos['Producción'].rolling(12).mean().plot(figsize=(10,4),label='Media Móvil c/12 meses')
datos['Producción'].plot()
plt.legend()
plt.show()

# %% [markdown]
# La funcion seasonal_decompose() de statsmodels, descompone la serie en tres partes: tendencia, estacionalidad y residuos.

# %%
decomp = seasonal_decompose(datos['Producción']
                            , period=12, extrapolate_trend='freq'
                            )
fig =decomp.plot()
fig.set_size_inches(10,7)

# %% [markdown]
# ## Estacionariedad de la Serie

# %% [markdown]
# Realizamos el **test Dickey-Fuller** en la cual, **la hipótesis nula es que los datos no son estacionarios** (*si p es muy pequeña, rechazaremos la hipotesis nula*)
# La hipotesis alternativa es que son estacionarios

# %%
p_value_adfuller(datos['Producción'])
# Out:
# P-value:  0.4533504471596746
# No se rechaza la hipóteis nula, los datos no son estacionarios

# %%
datos['1a diff']= datos['Producción'] - datos['Producción'].shift(1)
datos['1a diff'].plot(figsize=(10,4))
plt.show()

# %%
p_value_adfuller(datos['1a diff'].dropna())
# Out:
# P-value:  1.0639526450825224e-09
# Se rechaza la hipótesis nula, los datos son estacionarios

# %% [markdown]
# ## Visualización de la ACF y PACF

# %%
plot_acf(datos['1a diff'].dropna())
plot_pacf(datos['1a diff'].dropna())
plt.show()

# %% [markdown]
# # Construcción del modelo SARIMA

# %% [markdown]
# ## División de la serie en entrenamiento y prueba

# %%
from datetime import  timedelta
from dateutil.relativedelta import relativedelta

end_month =  datos.index.max()
split_month = end_month + relativedelta(months=-12)
split_month
# Out:
# Timestamp('2022-01-01 00:00:00', freq='MS')

# %%
train = datos.loc[:split_month,'Producción']
test = datos.loc[split_month:,'Producción']

# %%
train.plot(label = 'train', figsize =(10,4))
test.plot(label = 'test', figsize =(10,4))
plt.legend()
plt.show()

# %% [markdown]
# ## Orden del modelo ARIMA (pdq) y entrenamiento

# %%
p =  q = range(0, 3)
pdq = list(itertools.product(p, [1], q))
pdq
# Out:
# [(0, 1, 0),
#  (0, 1, 1),
#  (0, 1, 2),
#  (1, 1, 0),
#  (1, 1, 1),
#  (1, 1, 2),
#  (2, 1, 0),
#  (2, 1, 1),
#  (2, 1, 2)]

# %%
p = d =  q = range(0, 3)
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
seasonal_pdq
# Out:
# [(0, 0, 0, 12),
#  (0, 0, 1, 12),
#  (0, 0, 2, 12),
#  (0, 1, 0, 12),
#  (0, 1, 1, 12),
#  (0, 1, 2, 12),
#  (0, 2, 0, 12),
#  (0, 2, 1, 12),
#  (0, 2, 2, 12),
#  (1, 0, 0, 12),
#  (1, 0, 1, 12),
#  (1, 0, 2, 12),
#  (1, 1, 0, 12),
#  (1, 1, 1, 12),
#  (1, 1, 2, 12),
#  (1, 2, 0, 12),
#  (1, 2, 1, 12),
#  (1, 2, 2, 12),
#  (2, 0, 0, 12),
#  (2, 0, 1, 12),
#  (2, 0, 2, 12),
#  (2, 1, 0, 12),
#  (2, 1, 1, 12),
#  (2, 1, 2, 12),
#  (2, 2, 0, 12),
#  (2, 2, 1, 12),
#  (2, 2, 2, 12)]

# %%
aic_modelos = {}
for parametros in pdq:
  for parametros_s in seasonal_pdq:
      modelo = SARIMAX(train,
                       order = parametros,             # p, q, d
                       seasonal_order = parametros_s,  # p, q, d  de la temporalidad
                       enforce_stationarity = False,
                       enforce_invertibility = False   # permite que el polinomio de promedio móvil no sea invertible,
                                                       # de modo que la mayoría de los modelos sean estimables.
                       )
      results = modelo.fit()
      aic_modelos[parametros, parametros_s] = results.aic
      print('ARIMA{} x {} - AIC:{}'.format(parametros, parametros_s, results.aic))
# Out:
# ARIMA(0, 1, 0) x (0, 0, 0, 12) - AIC:1911.9389894338033
# ARIMA(0, 1, 0) x (0, 0, 1, 12) - AIC:1648.125312567458
# ARIMA(0, 1, 0) x (0, 0, 2, 12) - AIC:1497.6281173862913
# ARIMA(0, 1, 0) x (0, 1, 0, 12) - AIC:1419.9459736730503
# ARIMA(0, 1, 0) x (0, 1, 1, 12) - AIC:1268.527505708967
# ARIMA(0, 1, 0) x (0, 1, 2, 12) - AIC:1209.7075023120194
# ARIMA(0, 1, 0) x (0, 2, 0, 12) - AIC:1577.3384109987387
# ARIMA(0, 1, 0) x (0, 2, 1, 12) - AIC:1329.481266394319
# ARIMA(0, 1, 0) x (0, 2, 2, 12) - AIC:1196.4345818202141
# ARIMA(0, 1, 0) x (1, 0, 0, 12) - AIC:1418.9978584339397
# ARIMA(0, 1, 0) x (1, 0, 1, 12) - AIC:1324.219296847598
# ARIMA(0, 1, 0) x (1, 0, 2, 12) - AIC:1265.5628607917874
# ARIMA(0, 1, 0) x (1, 1, 0, 12) - AIC:1340.9461673139335
# ARIMA(0, 1, 0) x (1, 1, 1, 12) - AIC:1274.3166899411622
# ARIMA(0, 1, 0) x (1, 1, 2, 12) - AIC:1209.0819323951196
# ARIMA(0, 1, 0) x (1, 2, 0, 12) - AIC:1439.3975283167251
# ARIMA(0, 1, 0) x (1, 2, 1, 12) - AIC:1316.7959381736289
# ARIMA(0, 1, 0) x (1, 2, 2, 12) - AIC:1198.4306823113002
# ARIMA(0, 1, 0) x (2, 0, 0, 12) - AIC:1339.6930511956175
# ARIMA(0, 1, 0) x (2, 0, 1, 12) - AIC:1275.5503103591482
# ARIMA(0, 1, 0) x (2, 0, 2, 12) - AIC:1262.4595896168103
# ARIMA(0, 1, 0) x (2, 1, 0, 12) - AIC:1251.957358483115
# ARIMA(0, 1, 0) x (2, 1, 1, 12) - AIC:1209.0959948212728
# ARIMA(0, 1, 0) x (2, 1, 2, 12) - AIC:1206.2626169185683
# ARIMA(0, 1, 0) x (2, 2, 0, 12) - AIC:1323.377971230659
# ARIMA(0, 1, 0) x (2, 2, 1, 12) - AIC:1233.0205416735316
# ARIMA(0, 1, 0) x (2, 2, 2, 12) - AIC:1208.5454135512998
# ARIMA(0, 1, 1) x (0, 0, 0, 12) - AIC:1835.8646667569146
# ARIMA(0, 1, 1) x (0, 0, 1, 12) - AIC:1622.6050007639406
# ARIMA(0, 1, 1) x (0, 0, 2, 12) - AIC:1481.7768872513839
# ARIMA(0, 1, 1) x (0, 1, 0, 12) - AIC:1374.7007598581972
# ARIMA(0, 1, 1) x (0, 1, 1, 12) - AIC:1220.6591752948812
# ARIMA(0, 1, 1) x (0, 1, 2, 12) - AIC:1162.439992035308
# ARIMA(0, 1, 1) x (0, 2, 0, 12) - AIC:1531.996328084976
# ARIMA(0, 1, 1) x (0, 2, 1, 12) - AIC:1279.4396873668295
# ARIMA(0, 1, 1) x (0, 2, 2, 12) - AIC:1143.2574331068145
# ARIMA(0, 1, 1) x (1, 0, 0, 12) - AIC:1382.87953637467
# ARIMA(0, 1, 1) x (1, 0, 1, 12) - AIC:1271.730633542796
# ARIMA(0, 1, 1) x (1, 0, 2, 12) - AIC:1211.8297994400496
# ARIMA(0, 1, 1) x (1, 1, 0, 12) - AIC:1302.0781336292398
# ARIMA(0, 1, 1) x (1, 1, 1, 12) - AIC:1227.8109498579656
# ARIMA(0, 1, 1) x (1, 1, 2, 12) - AIC:1159.501448559623
# ARIMA(0, 1, 1) x (1, 2, 0, 12) - AIC:1405.0368554731085
# ARIMA(0, 1, 1) x (1, 2, 1, 12) - AIC:1271.499586479786
# ARIMA(0, 1, 1) x (1, 2, 2, 12) - AIC:1145.2496201083238
# ARIMA(0, 1, 1) x (2, 0, 0, 12) - AIC:1303.0464657136172
# ARIMA(0, 1, 1) x (2, 0, 1, 12) - AIC:1228.3331236496344
# ARIMA(0, 1, 1) x (2, 0, 2, 12) - AIC:1203.9055334074092
# ARIMA(0, 1, 1) x (2, 1, 0, 12) - AIC:1204.889344845311
# ARIMA(0, 1, 1) x (2, 1, 1, 12) - AIC:1159.3300650769336
# ARIMA(0, 1, 1) x (2, 1, 2, 12) - AIC:1148.5866721618017
# ARIMA(0, 1, 1) x (2, 2, 0, 12) - AIC:1291.4549384616298
# ARIMA(0, 1, 1) x (2, 2, 1, 12) - AIC:1187.494733087552
# ARIMA(0, 1, 1) x (2, 2, 2, 12) - AIC:1146.2152497670922
# ARIMA(0, 1, 2) x (0, 0, 0, 12) - AIC:1759.3655519152103
# ARIMA(0, 1, 2) x (0, 0, 1, 12) - AIC:1531.6858488947776
# ARIMA(0, 1, 2) x (0, 0, 2, 12) - AIC:1396.3009484070512
# ARIMA(0, 1, 2) x (0, 1, 0, 12) - AIC:1359.7316184344154
# ARIMA(0, 1, 2) x (0, 1, 1, 12) - AIC:1201.3761749795349
# ARIMA(0, 1, 2) x (0, 1, 2, 12) - AIC:1144.9180652273521
# ARIMA(0, 1, 2) x (0, 2, 0, 12) - AIC:1513.842068132246
# ARIMA(0, 1, 2) x (0, 2, 1, 12) - AIC:1262.4717406126565
# ARIMA(0, 1, 2) x (0, 2, 2, 12) - AIC:1130.8987604504987
# ARIMA(0, 1, 2) x (1, 0, 0, 12) - AIC:1364.3011642175682
# ARIMA(0, 1, 2) x (1, 0, 1, 12) - AIC:1257.4229479376534
# ARIMA(0, 1, 2) x (1, 0, 2, 12) - AIC:1199.5269128869065
# ARIMA(0, 1, 2) x (1, 1, 0, 12) - AIC:1291.453078840889
# ARIMA(0, 1, 2) x (1, 1, 1, 12) - AIC:1203.3758520715803
# ARIMA(0, 1, 2) x (1, 1, 2, 12) - AIC:1141.797826690603
# ARIMA(0, 1, 2) x (1, 2, 0, 12) - AIC:1393.7260570586693
# ARIMA(0, 1, 2) x (1, 2, 1, 12) - AIC:1255.770687332079
# ARIMA(0, 1, 2) x (1, 2, 2, 12) - AIC:1132.8978786234375
# ARIMA(0, 1, 2) x (2, 0, 0, 12) - AIC:1287.6841257921271
# ARIMA(0, 1, 2) x (2, 0, 1, 12) - AIC:1220.4862991582238
# ARIMA(0, 1, 2) x (2, 0, 2, 12) - AIC:1191.133106177367
# ARIMA(0, 1, 2) x (2, 1, 0, 12) - AIC:1186.488005191697
# ARIMA(0, 1, 2) x (2, 1, 1, 12) - AIC:1145.9633010514076
# ARIMA(0, 1, 2) x (2, 1, 2, 12) - AIC:1128.9290241497715
# ARIMA(0, 1, 2) x (2, 2, 0, 12) - AIC:1270.1271852097252
# ARIMA(0, 1, 2) x (2, 2, 1, 12) - AIC:1171.8342885040247
# ARIMA(0, 1, 2) x (2, 2, 2, 12) - AIC:1130.6015785184964
# ARIMA(1, 1, 0) x (0, 0, 0, 12) - AIC:1877.163147727517
# ARIMA(1, 1, 0) x (0, 0, 1, 12) - AIC:1638.5564509500564
# ARIMA(1, 1, 0) x (0, 0, 2, 12) - AIC:1498.8428771100544
# ARIMA(1, 1, 0) x (0, 1, 0, 12) - AIC:1398.065325770955
# ARIMA(1, 1, 0) x (0, 1, 1, 12) - AIC:1247.1714315139452
# ARIMA(1, 1, 0) x (0, 1, 2, 12) - AIC:1188.1448535164404
# ARIMA(1, 1, 0) x (0, 2, 0, 12) - AIC:1558.4103445465003
# ARIMA(1, 1, 0) x (0, 2, 1, 12) - AIC:1308.8003681882287
# ARIMA(1, 1, 0) x (0, 2, 2, 12) - AIC:1171.3826082526225
# ARIMA(1, 1, 0) x (1, 0, 0, 12) - AIC:1395.2796696092792
# ARIMA(1, 1, 0) x (1, 0, 1, 12) - AIC:1297.2984542746851
# ARIMA(1, 1, 0) x (1, 0, 2, 12) - AIC:1237.2614297685698
# ARIMA(1, 1, 0) x (1, 1, 0, 12) - AIC:1314.5424260489244
# ARIMA(1, 1, 0) x (1, 1, 1, 12) - AIC:1252.0609686697558
# ARIMA(1, 1, 0) x (1, 1, 2, 12) - AIC:1187.4841511833445
# ARIMA(1, 1, 0) x (1, 2, 0, 12) - AIC:1416.5802434106208
# ARIMA(1, 1, 0) x (1, 2, 1, 12) - AIC:1296.5360086028145
# ARIMA(1, 1, 0) x (1, 2, 2, 12) - AIC:1173.3783336211086
# ARIMA(1, 1, 0) x (2, 0, 0, 12) - AIC:1315.4927749116878
# ARIMA(1, 1, 0) x (2, 0, 1, 12) - AIC:1241.5528996710516
# ARIMA(1, 1, 0) x (2, 0, 2, 12) - AIC:1233.4126999593896
# ARIMA(1, 1, 0) x (2, 1, 0, 12) - AIC:1225.6258463454933
# ARIMA(1, 1, 0) x (2, 1, 1, 12) - AIC:1181.3482324666675
# ARIMA(1, 1, 0) x (2, 1, 2, 12) - AIC:1182.4561477641455
# ARIMA(1, 1, 0) x (2, 2, 0, 12) - AIC:1302.2825521795335
# ARIMA(1, 1, 0) x (2, 2, 1, 12) - AIC:1206.7376223436354
# ARIMA(1, 1, 0) x (2, 2, 2, 12) - AIC:1181.666454344085
# ARIMA(1, 1, 1) x (0, 0, 0, 12) - AIC:1837.127869424959
# ARIMA(1, 1, 1) x (0, 0, 1, 12) - AIC:1581.2115996229631
# ARIMA(1, 1, 1) x (0, 0, 2, 12) - AIC:1429.9425739743763
# ARIMA(1, 1, 1) x (0, 1, 0, 12) - AIC:1350.4598023419558
# ARIMA(1, 1, 1) x (0, 1, 1, 12) - AIC:1201.5120633482065
# ARIMA(1, 1, 1) x (0, 1, 2, 12) - AIC:1146.0137024429357
# ARIMA(1, 1, 1) x (0, 2, 0, 12) - AIC:1508.1275069287549
# ARIMA(1, 1, 1) x (0, 2, 1, 12) - AIC:1259.631236600329
# ARIMA(1, 1, 1) x (0, 2, 2, 12) - AIC:1131.652786638494
# ARIMA(1, 1, 1) x (1, 0, 0, 12) - AIC:1348.8413709173205
# ARIMA(1, 1, 1) x (1, 0, 1, 12) - AIC:1256.6793450385026
# ARIMA(1, 1, 1) x (1, 0, 2, 12) - AIC:1199.8352621735453
# ARIMA(1, 1, 1) x (1, 1, 0, 12) - AIC:1274.8026738693752
# ARIMA(1, 1, 1) x (1, 1, 1, 12) - AIC:1210.0622540886343
# ARIMA(1, 1, 1) x (1, 1, 2, 12) - AIC:1142.2269507279184
# ARIMA(1, 1, 1) x (1, 2, 0, 12) - AIC:1377.682379231957
# ARIMA(1, 1, 1) x (1, 2, 1, 12) - AIC:1253.6063173431407
# ARIMA(1, 1, 1) x (1, 2, 2, 12) - AIC:1133.6517383712307
# ARIMA(1, 1, 1) x (2, 0, 0, 12) - AIC:1273.3705063026155
# ARIMA(1, 1, 1) x (2, 0, 1, 12) - AIC:1210.1715123876122
# ARIMA(1, 1, 1) x (2, 0, 2, 12) - AIC:1191.7941122480743
# ARIMA(1, 1, 1) x (2, 1, 0, 12) - AIC:1178.3129485625882
# ARIMA(1, 1, 1) x (2, 1, 1, 12) - AIC:1139.066833414222
# ARIMA(1, 1, 1) x (2, 1, 2, 12) - AIC:1133.6616655673665
# ARIMA(1, 1, 1) x (2, 2, 0, 12) - AIC:1259.1274968692942
# ARIMA(1, 1, 1) x (2, 2, 1, 12) - AIC:1163.4946086583
# ARIMA(1, 1, 1) x (2, 2, 2, 12) - AIC:1136.1394894077198
# ARIMA(1, 1, 2) x (0, 0, 0, 12) - AIC:1743.3884362044332
# ARIMA(1, 1, 2) x (0, 0, 1, 12) - AIC:1526.4742896285993
# ARIMA(1, 1, 2) x (0, 0, 2, 12) - AIC:1395.6464281575563
# ARIMA(1, 1, 2) x (0, 1, 0, 12) - AIC:1345.0806317439897
# ARIMA(1, 1, 2) x (0, 1, 1, 12) - AIC:1198.1106786649261
# ARIMA(1, 1, 2) x (0, 1, 2, 12) - AIC:1142.5139003672207
# ARIMA(1, 1, 2) x (0, 2, 0, 12) - AIC:1502.3555258848653
# ARIMA(1, 1, 2) x (0, 2, 1, 12) - AIC:1254.9962208778047
# ARIMA(1, 1, 2) x (0, 2, 2, 12) - AIC:1127.8508503635944
# ARIMA(1, 1, 2) x (1, 0, 0, 12) - AIC:1350.8259964517206
# ARIMA(1, 1, 2) x (1, 0, 1, 12) - AIC:1253.3015591588758
# ARIMA(1, 1, 2) x (1, 0, 2, 12) - AIC:1196.6561115944087
# ARIMA(1, 1, 2) x (1, 1, 0, 12) - AIC:1275.0328274001408
# ARIMA(1, 1, 2) x (1, 1, 1, 12) - AIC:1200.1101541105957
# ARIMA(1, 1, 2) x (1, 1, 2, 12) - AIC:1139.6624873399637
# ARIMA(1, 1, 2) x (1, 2, 0, 12) - AIC:1378.532493976541
# ARIMA(1, 1, 2) x (1, 2, 1, 12) - AIC:1247.4080021305067
# ARIMA(1, 1, 2) x (1, 2, 2, 12) - AIC:1129.8502362698644
# ARIMA(1, 1, 2) x (2, 0, 0, 12) - AIC:1275.1390503955402
# ARIMA(1, 1, 2) x (2, 0, 1, 12) - AIC:1211.3030276650006
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ARIMA(1, 1, 2) x (2, 0, 2, 12) - AIC:1189.6059195931757
# ARIMA(1, 1, 2) x (2, 1, 0, 12) - AIC:1180.2625430366618
# ARIMA(1, 1, 2) x (2, 1, 1, 12) - AIC:1141.0663182200024
# ARIMA(1, 1, 2) x (2, 1, 2, 12) - AIC:1128.5841602284108
# ARIMA(1, 1, 2) x (2, 2, 0, 12) - AIC:1261.028499120743
# ARIMA(1, 1, 2) x (2, 2, 1, 12) - AIC:1165.4373341412922
# ARIMA(1, 1, 2) x (2, 2, 2, 12) - AIC:1131.0645333326388
# ARIMA(2, 1, 0) x (0, 0, 0, 12) - AIC:1740.0229582763195
# ARIMA(2, 1, 0) x (0, 0, 1, 12) - AIC:1584.2980800580533
# ARIMA(2, 1, 0) x (0, 0, 2, 12) - AIC:1468.3372226362453
# ARIMA(2, 1, 0) x (0, 1, 0, 12) - AIC:1376.400253065843
# ARIMA(2, 1, 0) x (0, 1, 1, 12) - AIC:1238.8749562618277
# ARIMA(2, 1, 0) x (0, 1, 2, 12) - AIC:1177.3385894084126
# ARIMA(2, 1, 0) x (0, 2, 0, 12) - AIC:1529.8724826190994
# ARIMA(2, 1, 0) x (0, 2, 1, 12) - AIC:1290.9745733030518
# ARIMA(2, 1, 0) x (0, 2, 2, 12) - AIC:1163.8619784105063
# ARIMA(2, 1, 0) x (1, 0, 0, 12) - AIC:1374.8499854849488
# ARIMA(2, 1, 0) x (1, 0, 1, 12) - AIC:1283.4636682565758
# ARIMA(2, 1, 0) x (1, 0, 2, 12) - AIC:1226.7035000060848
# ARIMA(2, 1, 0) x (1, 1, 0, 12) - AIC:1295.0283472827077
# ARIMA(2, 1, 0) x (1, 1, 1, 12) - AIC:1234.8884625024857
# ARIMA(2, 1, 0) x (1, 1, 2, 12) - AIC:1178.5716280043716
# ARIMA(2, 1, 0) x (1, 2, 0, 12) - AIC:1388.472962351882
# ARIMA(2, 1, 0) x (1, 2, 1, 12) - AIC:1274.7825591867804
# ARIMA(2, 1, 0) x (1, 2, 2, 12) - AIC:1165.8332492380678
# ARIMA(2, 1, 0) x (2, 0, 0, 12) - AIC:1296.3767806746919
# ARIMA(2, 1, 0) x (2, 0, 1, 12) - AIC:1227.748032973105
# ARIMA(2, 1, 0) x (2, 0, 2, 12) - AIC:1218.1706186211684
# ARIMA(2, 1, 0) x (2, 1, 0, 12) - AIC:1205.773594138795
# ARIMA(2, 1, 0) x (2, 1, 1, 12) - AIC:1162.9700414862016
# ARIMA(2, 1, 0) x (2, 1, 2, 12) - AIC:1164.3532570922403
# ARIMA(2, 1, 0) x (2, 2, 0, 12) - AIC:1284.8612418295224
# ARIMA(2, 1, 0) x (2, 2, 1, 12) - AIC:1188.4490653265775
# ARIMA(2, 1, 0) x (2, 2, 2, 12) - AIC:1163.0952010759825
# ARIMA(2, 1, 1) x (0, 0, 0, 12) - AIC:1570.3032415780413
# ARIMA(2, 1, 1) x (0, 0, 1, 12) - AIC:1439.3481637049722
# ARIMA(2, 1, 1) x (0, 0, 2, 12) - AIC:1363.9645169586856
# ARIMA(2, 1, 1) x (0, 1, 0, 12) - AIC:1351.1355639517992
# ARIMA(2, 1, 1) x (0, 1, 1, 12) - AIC:1203.3391104446541
# ARIMA(2, 1, 1) x (0, 1, 2, 12) - AIC:1147.8819459897702
# ARIMA(2, 1, 1) x (0, 2, 0, 12) - AIC:1509.725764611226
# ARIMA(2, 1, 1) x (0, 2, 1, 12) - AIC:1261.0074276952093
# ARIMA(2, 1, 1) x (0, 2, 2, 12) - AIC:1133.1339884603856
# ARIMA(2, 1, 1) x (1, 0, 0, 12) - AIC:1345.3188789746623
# ARIMA(2, 1, 1) x (1, 0, 1, 12) - AIC:1258.6459276838746
# ARIMA(2, 1, 1) x (1, 0, 2, 12) - AIC:1200.7618147592025
# ARIMA(2, 1, 1) x (1, 1, 0, 12) - AIC:1270.0356319986402
# ARIMA(2, 1, 1) x (1, 1, 1, 12) - AIC:1205.340087011358
# ARIMA(2, 1, 1) x (1, 1, 2, 12) - AIC:1144.2120392198938
# ARIMA(2, 1, 1) x (1, 2, 0, 12) - AIC:1390.3923538291701
# ARIMA(2, 1, 1) x (1, 2, 1, 12) - AIC:1254.5256840403867
# ARIMA(2, 1, 1) x (1, 2, 2, 12) - AIC:1135.13403886837
# ARIMA(2, 1, 1) x (2, 0, 0, 12) - AIC:1270.2647906691864
# ARIMA(2, 1, 1) x (2, 0, 1, 12) - AIC:1206.4060913120527
# ARIMA(2, 1, 1) x (2, 0, 2, 12) - AIC:1193.7675395521355
# ARIMA(2, 1, 1) x (2, 1, 0, 12) - AIC:1173.9425826946588
# ARIMA(2, 1, 1) x (2, 1, 1, 12) - AIC:1133.6642257262106
# ARIMA(2, 1, 1) x (2, 1, 2, 12) - AIC:1135.660753975305
# ARIMA(2, 1, 1) x (2, 2, 0, 12) - AIC:1255.9505533300212
# ARIMA(2, 1, 1) x (2, 2, 1, 12) - AIC:1160.2190194781579
# ARIMA(2, 1, 1) x (2, 2, 2, 12) - AIC:1138.0930813492846
# ARIMA(2, 1, 2) x (0, 0, 0, 12) - AIC:1467.1893992794003
# ARIMA(2, 1, 2) x (0, 0, 1, 12) - AIC:1355.0573075401735
# ARIMA(2, 1, 2) x (0, 0, 2, 12) - AIC:1292.5945184350767
# ARIMA(2, 1, 2) x (0, 1, 0, 12) - AIC:1349.0423765891646
# ARIMA(2, 1, 2) x (0, 1, 1, 12) - AIC:1200.1359994356894
# ARIMA(2, 1, 2) x (0, 1, 2, 12) - AIC:1144.4500944769284
# ARIMA(2, 1, 2) x (0, 2, 0, 12) - AIC:1495.2650876447278
# ARIMA(2, 1, 2) x (0, 2, 1, 12) - AIC:1257.9305704526512
# ARIMA(2, 1, 2) x (0, 2, 2, 12) - AIC:1130.3962386593666
# ARIMA(2, 1, 2) x (1, 0, 0, 12) - AIC:1347.2535958793956
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ARIMA(2, 1, 2) x (1, 0, 1, 12) - AIC:1255.2694067572104
# ARIMA(2, 1, 2) x (1, 0, 2, 12) - AIC:1198.497837465746
# ARIMA(2, 1, 2) x (1, 1, 0, 12) - AIC:1273.3657710875796
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ARIMA(2, 1, 2) x (1, 1, 1, 12) - AIC:1202.1368596869434
# ARIMA(2, 1, 2) x (1, 1, 2, 12) - AIC:1141.5246117924517
# ARIMA(2, 1, 2) x (1, 2, 0, 12) - AIC:1370.945248448471
# ARIMA(2, 1, 2) x (1, 2, 1, 12) - AIC:1251.2488921487611
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ARIMA(2, 1, 2) x (1, 2, 2, 12) - AIC:1133.1724629656067
# ARIMA(2, 1, 2) x (2, 0, 0, 12) - AIC:1272.0242765067615
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ARIMA(2, 1, 2) x (2, 0, 1, 12) - AIC:1208.390296530094
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ARIMA(2, 1, 2) x (2, 0, 2, 12) - AIC:1191.6414209921052
# ARIMA(2, 1, 2) x (2, 1, 0, 12) - AIC:1175.9769422646973
# ARIMA(2, 1, 2) x (2, 1, 1, 12) - AIC:1135.413698804183
# ARIMA(2, 1, 2) x (2, 1, 2, 12) - AIC:1130.2817737810692
# ARIMA(2, 1, 2) x (2, 2, 0, 12) - AIC:1257.7327011012644
# ARIMA(2, 1, 2) x (2, 2, 1, 12) - AIC:1162.2486330129254
# ARIMA(2, 1, 2) x (2, 2, 2, 12) - AIC:1132.2950193340807

# %% [markdown]
# El criterio de información de Akaike ([AIC](https://es.wikipedia.org/wiki/Criterio_de_informaci%C3%B3n_de_Akaike)) es una medida de la calidad relativa de un modelo estadístico, para un conjunto dado de datos.
#
# Considera la bondad de ajuste del modelo a los datos, pero también la complejidad del modelo (número de parámetros)
#
# AIC ofrece una estimación relativa de la información perdida cuando se utiliza un modelo determinado para representar el proceso que genera los datos

# %%
modelo = min(aic_modelos, key = aic_modelos.get)
print('Modelo: ', modelo )
print('AIC: ',min(aic_modelos.values()))
# Out:
# Modelo:  ((1, 1, 2), (0, 2, 2, 12))
# AIC:  1127.8508503635944

# %%
modelo = SARIMAX(train,
                 order = modelo[0],
                 seasonal_order = modelo[1],
                 enforce_stationarity = False,
                 enforce_invertibility = False)
resultados = modelo.fit()
print(resultados.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5397      0.218      2.472      0.013       0.112       0.968
# ma.L1         -1.1376      0.245     -4.634      0.000      -1.619      -0.656
# ma.L2          0.1848      0.210      0.879      0.379      -0.227       0.597
# ma.S.L12      -1.9772    672.381     -0.003      0.998   -1319.821    1315.866
# ma.S.L24       1.0000    680.162      0.001      0.999   -1332.094    1334.094
# sigma2         7.9999   5441.153      0.001      0.999   -1.07e+04    1.07e+04
# ==============================================================================

# %% [markdown]
# # Validación

# %% [markdown]
# ## Análisis de los residuos del modelo

# %%
resultados.plot_diagnostics(figsize = (16,8))
plt.show()

# %% [markdown]
# ##  Predicción y evaluación del modelo

# %%
pred = resultados.get_prediction(start = split_month,
                                 end =end_month)
pred.predicted_mean
# Out:
# 2022-01-01    118.628807
# 2022-02-01    110.615090
# 2022-03-01    101.154917
# 2022-04-01     88.014514
# 2022-05-01     90.339747
# 2022-06-01    102.760445
# 2022-07-01    114.530455
# 2022-08-01    112.260421
# 2022-09-01    100.373631
# 2022-10-01     91.414183
# 2022-11-01     96.730474
# 2022-12-01    111.218236
# 2023-01-01    120.816186
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
#intervalo de confianza
pred_IC = pred.conf_int()
pred_IC
# Out:
#             lower Producción  upper Producción
# 2022-01-01        112.825812        124.431802
# 2022-02-01        104.814402        116.415779
# 2022-03-01         94.908389        107.401444
# 2022-04-01         81.579707         94.449320
# 2022-05-01         83.808191         96.871303
# 2022-06-01         96.169307        109.351584
# 2022-07-01        107.896421        121.164488
# 2022-08-01        105.591563        118.929280
# 2022-09-01         93.674061        107.073201
# 2022-10-01         84.686082         98.142285
# 2022-11-01         89.975036        103.485912
# 2022-12-01        104.436142        118.000329
# 2023-01-01        114.007848        127.624525

# %%
fig = datos.loc[:,'Producción'].plot(label = 'Observaciones',
                                           figsize =(10,4))
pred.predicted_mean.plot(ax = fig, label = 'Prediciones')
fig.fill_between(pred_IC.index,
                 pred_IC.iloc[:,0], pred_IC.iloc[:,1],
                 color='k', alpha=.2)
plt.legend()
plt.show()

# %%
fig = datos.loc['2018-07-01':,'Producción'].plot(label = 'Observaciones',
                                           figsize =(10,4))
pred.predicted_mean.plot(ax = fig, label = 'Prediciones')
fig.fill_between(pred_IC.index,
                 pred_IC.iloc[:,0], pred_IC.iloc[:,1],
                 color='k', alpha=.2)
plt.legend()
plt.show()

# %%
y_pred  = pred.predicted_mean
y_real = datos.loc[split_month:end_month,'Producción']
mse = ((y_pred - y_real) ** 2).mean()
print('El error cuadrático medio es {}'.format(round(mse, 2)))
print('La raiz del error cuadrático medio es {}'.format(round(np.sqrt(mse), 2)))
# Out:
# El error cuadrático medio es 19.26
# La raiz del error cuadrático medio es 4.39

# %%
datos.head(10)
# Out:
#             Producción  1a diff
# DATE
# 2000-01-01    100.9623      NaN
# 2000-02-01     93.1065  -7.8558
# 2000-03-01     87.0234  -6.0831
# 2000-04-01     80.4433  -6.5801
# 2000-05-01     83.4549   3.0116
# 2000-06-01     89.9617   6.5068
# 2000-07-01     94.8591   4.8974
# 2000-08-01     98.1809   3.3218
# 2000-09-01     89.5896  -8.5913
# 2000-10-01     82.1295  -7.4601
